# %%
# Import Library
import pandas as pd
import numpy as np

# %%
# Import Dataset
date = "2023-12-19"
df_pres1 = pd.read_csv(f'./prabowo/Prabowo_{date}.csv', lineterminator='\n')
df_pres2 = pd.read_csv(f'./prabowo/2_Prabowo_{date}.csv', lineterminator='\n')
df_pres = pd.concat([df_pres1, df_pres2], axis=0, ignore_index=True)
df_pres = df_pres.drop_duplicates(subset=['full_text'])

df_wpres = pd.read_csv(f'./prabowo/Gibran_{date}.csv', lineterminator='\n')
df_acr = pd.read_csv(f'./prabowo/PraGi_{date}.csv', lineterminator='\n')

# %%
# count total data
print("Pres:", len(df_pres), " Wapres:", len(df_wpres), " Akronim:", len(df_acr))
total_data = len(df_pres) + len(df_wpres) + len(df_acr)
print("Total Data: ", total_data)
# Out:
# Pres: 417  Wapres: 173  Akronim: 16
# Total Data:  606

# %%
# merge dataset
df_pres['keyword'] = 'Pres'
df_wpres['keyword'] = 'Wapres'
df_acr['keyword'] = 'Akronim'
df = pd.concat([df_pres, df_wpres, df_acr], axis=0, ignore_index=True)
df
# Out:
#                     created_at               id_str  \
# 0    2023-12-19 00:04:13+07:00  1736794508548092228
# 1    2023-12-19 00:04:34+07:00  1736794596817219656
# 2    2023-12-19 00:16:39+07:00  1736797636555157711
# 3    2023-12-19 00:39:37+07:00  1736803416578699342
# 4    2023-12-19 00:43:54+07:00  1736804495777313161
# ..                         ...                  ...
# 601  2023-12-19 15:51:32+07:00  1737032909188628916
# 602  2023-12-19 17:31:54+07:00  1737058167308349694
# 603  2023-12-19 20:14:40+07:00  1737099128499572754
# 604  2023-12-19 22:21:14+07:00  1737130978563543258
# 605  2023-12-19 23:32:38+07:00  1737148949159645419
#
#                                              full_text  quote_count  \
# 0    @RomitsuT Itu pk kievlan zein dan IB HRS yg ma...            0
# 1    @KEBUMENinLOVE @CNNIndonesia Saya bersama Prab...            2
# 2    Serikat Tani dan Nelayan (STN) DPW Prima Jabar...            0
# 3    @PartaiSocmed Kata gua drpd sibuk cari aib Pas...            0
# 4    Seperti Nya Masyarakat Kita Sedang Bercanda😎  ...            0
# ..                                                 ...          ...
# 601  makan siang program Prabowo Gibran dalam menci...            0
# 602  @Naz_lira aku padahal sdh bantu pilih Pragi lo...            0
# 603  @Heraloebss BETUL HASIL SURVEY LSI PENDUKUNG P...            0
# 604  @muh_adam222 @Gus_Raharjo @ganjarpranowo Perta...            1
# 605  VISI MISI nya Paslon 2 PraGi semakin terlihat ...            0
#
#      reply_count  retweet_count  favorite_count lang          user_id_str  \
# 0              6             34             323   in  1690959664324964352
# 1              2              5               8   in            576755999
# 2              0              5              16   in  1378725801101684736
# 3              3              2              11   in           1535529703
# 4              1             14              27   in  1389082210452443138
# ..           ...            ...             ...  ...                  ...
# 601            0              0               1   in  1424573456029347840
# 602            0              0               1   in  1715707462576476160
# 603            0              0               0   in  1676744369855148033
# 604            0              0               0   in  1424573456029347840
# 605            0              0               0   in           4597496354
#
#      conversation_id_str         username  \
# 0    1736770952263024949   AmboyRoha31938
# 1    1375473694261141507      bengkeldodo
# 2    1736797636555157711         DpwPrima
# 3    1736782363148095988        cules0409
# 4    1736804495777313161     sami86pilang
# ..                   ...              ...
# 601  1737032906324037901  firman__nurhuda
# 602  1736989638643024097    elde_barge123
# 603  1736913785913479265       indank1982
# 604  1736779325733818400  firman__nurhuda
# 605  1737146350205391053   MaliminRinaldi
#
#                                              tweet_url  \
# 0    https://twitter.com/AmboyRoha31938/status/1736...
# 1    https://twitter.com/bengkeldodo/status/1736794...
# 2    https://twitter.com/DpwPrima/status/1736797636...
# 3    https://twitter.com/cules0409/status/173680341...
# 4    https://twitter.com/sami86pilang/status/173680...
# ..                                                 ...
# 601  https://twitter.com/firman__nurhuda/status/173...
# 602  https://twitter.com/elde_barge123/status/17370...
# 603  https://twitter.com/indank1982/status/17370991...
# 604  https://twitter.com/firman__nurhuda/status/173...
# 605  https://twitter.com/MaliminRinaldi/status/1737...
#
#                                              image_url  \
# 0                                                  NaN
# 1    https://pbs.twimg.com/ext_tw_video_thumb/17367...
# 2    https://pbs.twimg.com/ext_tw_video_thumb/17367...
# 3                                                  NaN
# 4    https://pbs.twimg.com/tweet_video_thumb/GBpeej...
# ..                                                 ...
# 601                                                NaN
# 602                                                NaN
# 603                                                NaN
# 604    https://pbs.twimg.com/media/GBuHaU5aQAAk9vC.jpg
# 605                                                NaN
#
#                    location  keyword
# 0                       NaN     Pres
# 1        Kebumen, Indonesia     Pres
# 2      West Java, Indonesia     Pres
# 3                    bekasi     Pres
# 4           PLANET TERINDAH     Pres
# ..                      ...      ...
# 601  Republic Of Indonesia   Akronim
# 602                     NaN  Akronim
# 603                     NaN  Akronim
# 604  Republic Of Indonesia   Akronim
# 605     Pancoran, Indonesia  Akronim
#
# [606 rows x 15 columns]

# %%
# count duplicate data
print("Duplicate Data: ", df.duplicated().sum())
# Out:
# Duplicate Data:  0

# %%
# count duplicate data based on full_text
print("Duplicate Data by Text: ", df['full_text'].duplicated().sum())
# Out:
# Duplicate Data by Text:  82

# %%
# drop duplicate data based on full_text
df = df.drop_duplicates(subset=['full_text'])
print("Total Data after Drop: ", len(df))
# Out:
# Total Data after Drop:  524

# %%
# sort data by created_at
df = df.sort_values(by=['created_at'])
df
# Out:
#                     created_at               id_str  \
# 0    2023-12-19 00:04:13+07:00  1736794508548092228
# 1    2023-12-19 00:04:34+07:00  1736794596817219656
# 2    2023-12-19 00:16:39+07:00  1736797636555157711
# 3    2023-12-19 00:39:37+07:00  1736803416578699342
# 418  2023-12-19 00:41:45+07:00  1736803954619822440
# ..                         ...                  ...
# 587  2023-12-19 23:47:34+07:00  1737152708027822387
# 414  2023-12-19 23:48:49+07:00  1737153020809654543
# 415  2023-12-19 23:55:22+07:00  1737154667837337900
# 588  2023-12-19 23:58:39+07:00  1737155495654535324
# 416  2023-12-19 23:58:45+07:00  1737155520111480965
#
#                                              full_text  quote_count  \
# 0    @RomitsuT Itu pk kievlan zein dan IB HRS yg ma...            0
# 1    @KEBUMENinLOVE @CNNIndonesia Saya bersama Prab...            2
# 2    Serikat Tani dan Nelayan (STN) DPW Prima Jabar...            0
# 3    @PartaiSocmed Kata gua drpd sibuk cari aib Pas...            0
# 418  Bawaslu DKI nyatakan deklarasi desa bersatu ya...            1
# ..                                                 ...          ...
# 587  Tepat sebelum nya Melki mengajak Pangeran Gibr...            3
# 414  Pendapat Rocky Gerung tentang Prabowo . https:...            0
# 415                 Saking cintanya sama PAK PRABOWO 🤣            3
# 588  @ch_chotimah2 @ZUL_Hasan @jokowi @gibran_tweet...            1
# 416  Pernyataan Zulhas Sudah Masuk Penistaan Agama ...            0
#
#      reply_count  retweet_count  favorite_count lang          user_id_str  \
# 0              6             34             323   in  1690959664324964352
# 1              2              5               8   in            576755999
# 2              0              5              16   in  1378725801101684736
# 3              3              2              11   in           1535529703
# 418            1              6              25   in  1247512756925763589
# ..           ...            ...             ...  ...                  ...
# 587            4             15              64   in  1464448807429623817
# 414            0              9              11   in  1129672753651388416
# 415           27            135             761   in            318872893
# 588            1              2               7   in  1422218616892583936
# 416            2             21              21   in  1161226499157942272
#
#      conversation_id_str         username  \
# 0    1736770952263024949   AmboyRoha31938
# 1    1375473694261141507      bengkeldodo
# 2    1736797636555157711         DpwPrima
# 3    1736782363148095988        cules0409
# 418  1736803954619822440         akupadi5
# ..                   ...              ...
# 587  1737152708027822387    PreciosaKanti
# 414  1737153020809654543    H4T14K4LN4L42
# 415  1737154667837337900    MamatAlkatiri
# 588  1737141896265474439    AmaludinYadin
# 416  1737155520111480965  Sherly0ctaviany
#
#                                              tweet_url  \
# 0    https://twitter.com/AmboyRoha31938/status/1736...
# 1    https://twitter.com/bengkeldodo/status/1736794...
# 2    https://twitter.com/DpwPrima/status/1736797636...
# 3    https://twitter.com/cules0409/status/173680341...
# 418  https://twitter.com/akupadi5/status/1736803954...
# ..                                                 ...
# 587  https://twitter.com/PreciosaKanti/status/17371...
# 414  https://twitter.com/H4T14K4LN4L42/status/17371...
# 415  https://twitter.com/MamatAlkatiri/status/17371...
# 588  https://twitter.com/AmaludinYadin/status/17371...
# 416  https://twitter.com/Sherly0ctaviany/status/173...
#
#                                              image_url              location  \
# 0                                                  NaN                   NaN
# 1    https://pbs.twimg.com/ext_tw_video_thumb/17367...    Kebumen, Indonesia
# 2    https://pbs.twimg.com/ext_tw_video_thumb/17367...  West Java, Indonesia
# 3                                                  NaN                bekasi
# 418  https://pbs.twimg.com/ext_tw_video_thumb/17368...           Ahokers 🤟🤟🤟
# ..                                                 ...                   ...
# 587                                                NaN     San Francisco, CA
# 414  https://pbs.twimg.com/ext_tw_video_thumb/17371...                   NaN
# 415                                                NaN   Fakfak - Yogyakarta
# 588                                                NaN                   NaN
# 416  https://pbs.twimg.com/ext_tw_video_thumb/17371...            Everywhere
#
#     keyword
# 0      Pres
# 1      Pres
# 2      Pres
# 3      Pres
# 418  Wapres
# ..      ...
# 587  Wapres
# 414    Pres
# 415    Pres
# 588  Wapres
# 416    Pres
#
# [524 rows x 15 columns]

# %%
len(df_acr)
# Out:
# 16

# %%
# count df with keyword Akronim
len(df[df['keyword'] == 'Akronim'])
# Out:
# 16

# %%
# export dataset
df.to_csv(f'./cleaned_dataset/paslon2/PraGi_{date}.csv', index=False)
