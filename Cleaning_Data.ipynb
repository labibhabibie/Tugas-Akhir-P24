# %%
# Import Library
import pandas as pd
import numpy as np

# %%
# Import Dataset
date = "2023-12-29"

# df_pres = pd.read_csv(f'./prabowo/Prabowo_{date}.csv', lineterminator='\n')
df_pres1 = pd.read_csv(f'./prabowo/Prabowo_{date}.csv', lineterminator='\n')
df_pres2 = pd.read_csv(f'./prabowo/2_Prabowo_{date}.csv', lineterminator='\n')
df_pres = pd.concat([df_pres1, df_pres2], axis=0, ignore_index=True)
df_pres = df_pres.drop_duplicates(subset=['full_text'])

df_wpres = pd.read_csv(f'./prabowo/Gibran_{date}.csv', lineterminator='\n')
# df_wpres1 = pd.read_csv(f'./prabowo/Gibran_{date}.csv', lineterminator='\n')
# df_wpres2 = pd.read_csv(f'./prabowo/2_Gibran_{date}.csv', lineterminator='\n')
# df_wpres = pd.concat([df_wpres1, df_wpres2], axis=0, ignore_index=True)
# df_wpres = df_wpres.drop_duplicates(subset=['full_text'])

df_acr = pd.read_csv(f'./prabowo/PraGi_{date}.csv', lineterminator='\n')

# %%
# count total data
print("Pres:", len(df_pres), " Wapres:", len(df_wpres), " Akronim:", len(df_acr))
total_data = len(df_pres) + len(df_wpres) + len(df_acr)
print("Total Data: ", total_data)
# Out:
# Pres: 434  Wapres: 193  Akronim: 16
# Total Data:  643

# %%
# merge dataset
df_pres['keyword'] = 'Pres'
df_wpres['keyword'] = 'Wapres'
df_acr['keyword'] = 'Akronim'
df = pd.concat([df_pres, df_wpres, df_acr], axis=0, ignore_index=True)
df
# Out:
#                     created_at               id_str  \
# 0    2023-12-29 11:46:46+07:00  1740595188115149214
# 1    2023-12-29 11:47:07+07:00  1740595278061920365
# 2    2023-12-29 11:57:05+07:00  1740597787581104437
# 3    2023-12-29 12:00:30+07:00  1740598645815464283
# 4    2023-12-29 12:02:08+07:00  1740599054906937707
# ..                         ...                  ...
# 638  2023-12-29 19:10:48+07:00  1740706932137279902
# 639  2023-12-29 20:30:50+07:00  1740727074783183041
# 640  2023-12-29 22:18:44+07:00  1740754228195569790
# 641  2023-12-29 22:58:04+07:00  1740764128321683653
# 642  2023-12-29 05:27:15+07:00  1740499681875300525
#
#                                              full_text  quote_count  \
# 0    Hitungan dri mana hemat 17T ?  Lah anggaran ma...            2
# 1    Sejumlah kader Partai Persatuan Pembangunan ( ...            9
# 2    @kurawa Dri vidio ini sngat jelas ini kampanye...            0
# ...

# %%
# count duplicate data
print("Duplicate Data: ", df.duplicated().sum())
# Out:
# Duplicate Data:  0

# %%
# count duplicate data based on full_text
print("Duplicate Data by Text: ", df['full_text'].duplicated().sum())
# Out:
# Duplicate Data by Text:  101

# %%
# drop duplicate data based on full_text
df = df.drop_duplicates(subset=['full_text'])
print("Total Data after Drop: ", len(df))
# Out:
# Total Data after Drop:  542

# %%
# sort data by created_at
df = df.sort_values(by=['created_at'])
df
# Out:
#                     created_at               id_str  \
# 392  2023-12-29 00:01:18+07:00  1740417653020487941
# 393  2023-12-29 00:22:25+07:00  1740422966536773792
# 394  2023-12-29 00:22:27+07:00  1740422973444776310
# 395  2023-12-29 00:30:33+07:00  1740425013583560774
# 396  2023-12-29 00:36:09+07:00  1740426423222055184
# ..                         ...                  ...
# 266  2023-12-29 23:39:05+07:00  1740774448742158823
# 615  2023-12-29 23:47:19+07:00  1740776520808047003
# 616  2023-12-29 23:47:34+07:00  1740776582560776589
# 267  2023-12-29 23:53:43+07:00  1740778131668206035
# 268  2023-12-29 23:56:27+07:00  1740778818405912741
#
#                                              full_text  quote_count  \
# 392  Pengamat Nilai Prabowo Pemimpin Paling Memaham...            2
# 393      prabowo kalo jadi presiden kiamat makin cepet            0
# 394  PRABOWO No More AMIN Forever ✊️🇮🇩 #GibranAntiP...            0
# ...

# %%
len(df_acr)
# Out:
# 16

# %%
# count df with keyword Akronim
len(df[df['keyword'] == 'Akronim'])
# Out:
# 16

# %%
# export dataset
df.to_csv(f'./cleaned_dataset/paslon2/PraGi_{date}.csv', index=False)
