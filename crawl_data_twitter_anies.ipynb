# %% [markdown]
# <a href="https://colab.research.google.com/github/labibhabibie/Tugas-Akhir-P24/blob/main/crawl_data_twitter_anies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Crawling Twitter Data based on **Search Keyword** Using `tweet-harvest`
# Last updated by Helmi Satria (helmisatria.com) on September 22, 2023
#
# Note: **For educational purposes only**

# %% [markdown]
# ## Import Library

# %%
# Import required Python package
# !pip install pandas

# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Hit:4 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:5 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:6 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:7 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:8 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,046 kB]
# Get:9 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,326 kB]
# Hit:10 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Hit:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [1,599 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,305 kB]
# Fetched 5,509 kB in 2s (2,796 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ca-certificates is already the newest version (20230311ubuntu0.22.04.1).
# curl is already the newest version (7.81.0-1ubuntu1.15).
# gnupg is already the newest version (2.2.27-3ubuntu2.1).
# gnupg set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 27 not upgraded.
# deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_20.x nodistro main
# Hit:1 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:6 https://deb.nodesource.com/node_20.x nodistro InRelease [12.1 kB]
# Hit:7 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:12 https://deb.nodesource.com/node_20.x nodistro/main amd64 Packages [4,270 B]
# Fetched 16.4 kB in 2s (8,800 B/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   nodejs
# 0 upgraded, 1 newly installed, 0 to remove and 27 not upgraded.
# Need to get 31.3 MB of archives.
# After this operation, 195 MB of additional disk space will be used.
# Get:1 https://deb.nodesource.com/node_20.x nodistro/main amd64 nodejs amd64 20.10.0-1nodesource1 [31.3 MB]
# Fetched 31.3 MB in 1s (58.6 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package nodejs.
# (Reading database ... 121658 files and directories currently installed.)
# Preparing to unpack .../nodejs_20.10.0-1nodesource1_amd64.deb ...
# Unpacking nodejs (20.10.0-1nodesource1) ...
# Setting up nodejs (20.10.0-1nodesource1) ...
# Processing triggers for man-db (2.10.2-1) ...
# v20.10.0

# %% [markdown]
# ## Parameter Crawl

# %%
import pandas as pd

tanggal = '2023-12-19'
token = "58a466c43a96363fa265014f7e3e96f9cbf2da2a"
limit = 5000

# %%
from google.colab import drive
drive.mount('/content/drive/')
path_drive = '/content/drive/MyDrive/ScrapingX/'
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# ## Anies

# %%
# Crawl Data Twitter
paslon = 'Anies'
filename = f'{paslon}_{tanggal}.csv'

search_keyword = f'{paslon} since:{tanggal}_00:00:00_WIB until:{tanggal}_23:59:59_WIB'

# !npx --yes tweet-harvest@latest -o "{filename}" -s "{search_keyword}" -l {limit} --token {token}
# Out:
# Welcome to the Twitter Crawler 🕷️
#
# This script uses Chromium Browser to crawl data from Twitter with *your* Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# up to date, audited 4 packages in 661ms
#
# found 0 vulnerabilities
# Installing dependencies...
# Hit:1 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:6 https://deb.nodesource.com/node_20.x nodistro InRelease
# Hit:7 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-freefont-ttf is already the newest version (20120503-10build1).
# fonts-liberation is already the newest version (1:1.07.4-11).
# libasound2 is already the newest version (1.2.6.1-1ubuntu1).
# libatk-bridge2.0-0 is already the newest version (2.38.0-3).
# libatk1.0-0 is already the newest version (2.36.0-3build1).
# libatspi2.0-0 is already the newest version (2.44.0-3).
# libcairo2 is already the newest version (1.16.0-5ubuntu2).
# libfontconfig1 is already the newest version (2.13.1-4.2ubuntu5).
# libnspr4 is already the newest version (2:4.32-3build1).
# libxcb1 is already the newest version (1.14-3ubuntu3).
# libxcomposite1 is already the newest version (1:0.4.5-1build2).
# libxdamage1 is already the newest version (1:1.1.5-2build2).
# libxext6 is already the newest version (2:1.3.4-1build1).
# libxfixes3 is already the newest version (1:6.0.0-1).
# libxkbcommon0 is already the newest version (1.4.0-1).
# libxrandr2 is already the newest version (2:1.5.2-1build1).
# xfonts-scalable is already the newest version (1:1.0.3-1.2ubuntu1).
# fonts-ipafont-gothic is already the newest version (00303-21ubuntu1).
# fonts-tlwg-loma-otf is already the newest version (1:0.7.3-1).
# fonts-unifont is already the newest version (1:14.0.01-1).
# fonts-wqy-zenhei is already the newest version (0.9.45-8).
# xfonts-cyrillic is already the newest version (1:1.0.5).
# fonts-noto-color-emoji is already the newest version (2.042-0ubuntu0.22.04.1).
# libcups2 is already the newest version (2.4.1op1-1ubuntu4.7).
# libdbus-1-3 is already the newest version (1.12.20-2ubuntu4.1).
# libdrm2 is already the newest version (2.4.113-2~ubuntu0.22.04.1).
# libfreetype6 is already the newest version (2.11.1+dfsg-1ubuntu0.2).
# libgbm1 is already the newest version (23.0.4-0ubuntu1~22.04.1).
# libglib2.0-0 is already the newest version (2.72.4-0ubuntu2.2).
# libnss3 is already the newest version (2:3.68.2-0ubuntu1.2).
# libpango-1.0-0 is already the newest version (1.50.6+ds-2ubuntu1).
# libwayland-client0 is already the newest version (1.20.0-1ubuntu0.1).
# libx11-6 is already the newest version (2:1.7.5-1ubuntu0.3).
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.5).
# 0 upgraded, 0 newly installed, 0 to remove and 27 not upgraded.
#
# Opening twitter search page...
#
#
# Filling in keywords: Anies since:2023-12-19_00:00:00_WIB until:2023-12-19_23:59:59_WIB
#
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/Anies_2023-12-19.csv
# Total tweets saved: 19
#
# Got some tweets, saving to file...
# Scrolling more...
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/Anies_2023-12-19.csv
# Total tweets saved: 39
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/Anies_2023-12-19.csv
# Total tweets saved: 59
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/Anies_2023-12-19.csv
# Total tweets saved: 79
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/Anies_2023-12-19.csv
# Total tweets saved: 99
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/Anies_2023-12-19.csv
# Total tweets saved: 119
#
# --Taking a break, waiting for 10 seconds...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/Anies_2023-12-19.csv
# Total tweets saved: 139
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/Anies_2023-12-19.csv
# Total tweets saved: 159
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/Anies_2023-12-19.csv
# Total tweets saved: 179
#
# Got some tweets, saving to file...
# Error parsing response json: {"_type":"Response","_guid":"response@749664d6b68688604591028c09bdb9eb"}
# Most likely, you have already exceeded the Twitter rate limit. Read more on https://twitter.com/elonmusk/status/1675187969420828672?s=46.
#
# Got some tweets, saving to file...
#
# Got some tweets, saving to file...
# Error parsing response json: {"_type":"Response","_guid":"response@47975d2c6970c695025fed5785738d8e"}
# Most likely, you have already exceeded the Twitter rate limit. Read more on https://twitter.com/elonmusk/status/1675187969420828672?s=46.
#
# Got some tweets, saving to file...
# Error parsing response json: {"_type":"Response","_guid":"response@447498a70edd3701e931fbf2c5cfed9c"}
# Most likely, you have already exceeded the Twitter rate limit. Read more on https://twitter.com/elonmusk/status/1675187969420828672?s=46.
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/Anies_2023-12-19.csv
# Total tweets saved: 199
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/Anies_2023-12-19.csv
# Total tweets saved: 219
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/Anies_2023-12-19.csv
# Total tweets saved: 239
#
# --Taking a break, waiting for 10 seconds...
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/Anies_2023-12-19.csv
# Total tweets saved: 258
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/Anies_2023-12-19.csv
# Total tweets saved: 271
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/Anies_2023-12-19.csv
# Total tweets saved: 275
#
# Got some tweets, saving to file...
#
# Got some tweets, saving to file...
#
# Got some tweets, saving to file...
# No more tweets found, please check your search criteria and csv file result
# Scrolling more...
# Scrolling more...
# Scrolling more...
# Scrolling more...
# Already got 275 tweets, done scrolling...

# %%
# Specify the path to your CSV file
file_path = f"tweets-data/{filename}"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path)

# sort by created_at
df = df.sort_values(by=['created_at'])

# change datetime to Asia/Jakarta
df['created_at'] = pd.to_datetime(df['created_at'])
df['created_at'] = df['created_at'].dt.tz_convert('Asia/Jakarta')

# Display the DataFrame
display(df)
# Out:
#                    created_at               id_str  \
# 258 2023-12-19 00:08:59+07:00  1736795708534272032
# 148 2023-12-19 00:11:49+07:00  1736796420190122020
# 272 2023-12-19 00:12:25+07:00  1736796570321138059
# 44  2023-12-19 00:22:41+07:00  1736799153643303064
# 108 2023-12-19 00:30:21+07:00  1736801083304104367
# ..                        ...                  ...
# 267 2023-12-19 23:13:52+07:00  1737144223877726626
# 196 2023-12-19 23:20:37+07:00  1737145925683085568
# 191 2023-12-19 23:26:06+07:00  1737147302240993762
# 76  2023-12-19 23:26:35+07:00  1737147425499009089
# 190 2023-12-19 23:51:09+07:00  1737153608725246399
#
#                                              full_text  quote_count  \
# 258                      @Hasbil_Lbs Anies is the best            0
# 148  DKI di bawah Pak Anies  mengurangi kemacetan  ...            0
# 272   @kurawa All in Anies Baswedan menang presiden RI            0
# 44   Nih Dengerin yang bilang Pak Anies Intoleran  ...            2
# 108  y’all are so unserious bc how is a pink babydo...            6
# ..                                                 ...          ...
# 267  Lihat video TIM ANIES +62! #TikTok https://t.c...            0
# 196  @bassIightyear GOJO PLEASEEEE IT WAS SUPPOSED ...            0
# 191  Kesekian kalinya acara Anies Baswedan dihadang...            1
# 76   Wakil Presiden RI ke-10 dan ke-12 Jusuf Kalla ...           12
# 190  @fullmoonfolks Betul  bang  kasian si Anies bi...            1
#
#      reply_count  retweet_count  favorite_count lang          user_id_str  \
# 258            0              0               2   en  1489813970047291397
# 148            0             41              81   in  1537213103397830656
# 272            0              0               0   in  1428173032829296641
# 44             5             77             124   in  1249004237004009474
# 108            4             63             707   en  1591331785601945604
# ..           ...            ...             ...  ...                  ...
# 267            0              0               0   en  1524498829898256384
# 196            1              1               0   en  1178170701536063488
# 191            6            122             169   in  1038483432391634944
# 76            13            244             578   in             46693036
# 190            6             19             220   in  1504205389130207235
#
#      conversation_id_str        username  \
# 258  1736706852094988751    Tong78641847
# 148  1736796420190122020  SemutMerah2024
# 272  1736590946186523030   setiaku_riyan
# 44   1736799153643303064    Gojekmilitan
# 108  1736801083304104367         j3anies
# ..                   ...             ...
# 267  1737144223877726626        MizziTar
# 196  1737143682812494256         keonhie
# 191  1737147302240993762        RomitsuT
# 76   1737147425499009089    inilahdotcom
# 190  1737151272896377292      kerrdrogba
#
#                                              tweet_url  \
# 258  https://twitter.com/Tong78641847/status/173679...
# 148  https://twitter.com/SemutMerah2024/status/1736...
# 272  https://twitter.com/setiaku_riyan/status/17367...
# 44   https://twitter.com/Gojekmilitan/status/173679...
# 108  https://twitter.com/j3anies/status/17368010833...
# ..                                                 ...
# 267  https://twitter.com/MizziTar/status/1737144223...
# 196  https://twitter.com/keonhie/status/17371459256...
# 191  https://twitter.com/RomitsuT/status/1737147302...
# 76   https://twitter.com/inilahdotcom/status/173714...
# 190  https://twitter.com/kerrdrogba/status/17371536...
#
#                                              image_url                location
# 258                                                NaN                     NaN
# 148    https://pbs.twimg.com/media/GBpXI0ObsAE1Lbj.jpg     Klaten, Jawa Tengah
# 272                                                NaN                     NaN
# 44   https://pbs.twimg.com/ext_tw_video_thumb/17367...  DKI Jakarta, Indonesia
# 108    https://pbs.twimg.com/media/GBpbYNqXEAAe5QJ.jpg     room 227 | she/her
# ..                                                 ...                     ...
# 267                                                NaN                     NaN
# 196  https://pbs.twimg.com/tweet_video_thumb/GBoJlI...         any pronouns 25
# 191                                                NaN                     NaN
# 76                                                 NaN                     NaN
# 190                                                NaN               Australia
#
# [275 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 275 entries, 258 to 190
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   created_at           275 non-null    datetime64[ns, Asia/Jakarta]
#  1   id_str               275 non-null    int64
#  2   full_text            275 non-null    object
#  3   quote_count          275 non-null    int64
#  4   reply_count          275 non-null    int64
#  5   retweet_count        275 non-null    int64
#  6   favorite_count       275 non-null    int64
#  7   lang                 275 non-null    object
#  8   user_id_str          275 non-null    int64
#  9   conversation_id_str  275 non-null    int64
#  10  username             275 non-null    object
#  11  tweet_url            275 non-null    object
#  12  image_url            190 non-null    object
#  13  location             129 non-null    object
# dtypes: datetime64[ns, Asia/Jakarta](1), int64(7), object(6)
# memory usage: 32.2+ KB

# %%
# export to csv
try:
    df.to_csv(f'{path_drive}{filename}', index=False)
    message = f"Berhasil menyimpan file: {filename}"
    print(message)
except:
    message = f"Gagal menyimpan file: {filename}"
    print(message)
# Out:
# Berhasil menyimpan file: Anies_2023-12-19.csv

# %% [markdown]
# ## Muhaimin

# %%
# Crawl Data Twitter
paslon2 = 'Muhaimin'
# tanggal = '2023-12-14'
filename2 = f'{paslon2}_{tanggal}.csv'

search_keyword2 = f'{paslon2} since:{tanggal}_00:00:00_WIB until:{tanggal}_23:59:59_WIB'
# limit = 5000

# !npx --yes tweet-harvest@latest -o "{filename2}" -s "{search_keyword2}" -l {limit} --token {token}
# Out:
# Welcome to the Twitter Crawler 🕷️
#
# This script uses Chromium Browser to crawl data from Twitter with *your* Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# up to date, audited 4 packages in 1s
#
# found 0 vulnerabilities
# Installing dependencies...
# Hit:1 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 https://deb.nodesource.com/node_20.x nodistro InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-freefont-ttf is already the newest version (20120503-10build1).
# fonts-liberation is already the newest version (1:1.07.4-11).
# libasound2 is already the newest version (1.2.6.1-1ubuntu1).
# libatk-bridge2.0-0 is already the newest version (2.38.0-3).
# libatk1.0-0 is already the newest version (2.36.0-3build1).
# libatspi2.0-0 is already the newest version (2.44.0-3).
# libcairo2 is already the newest version (1.16.0-5ubuntu2).
# libfontconfig1 is already the newest version (2.13.1-4.2ubuntu5).
# libnspr4 is already the newest version (2:4.32-3build1).
# libxcb1 is already the newest version (1.14-3ubuntu3).
# libxcomposite1 is already the newest version (1:0.4.5-1build2).
# libxdamage1 is already the newest version (1:1.1.5-2build2).
# libxext6 is already the newest version (2:1.3.4-1build1).
# libxfixes3 is already the newest version (1:6.0.0-1).
# libxkbcommon0 is already the newest version (1.4.0-1).
# libxrandr2 is already the newest version (2:1.5.2-1build1).
# xfonts-scalable is already the newest version (1:1.0.3-1.2ubuntu1).
# fonts-ipafont-gothic is already the newest version (00303-21ubuntu1).
# fonts-tlwg-loma-otf is already the newest version (1:0.7.3-1).
# fonts-unifont is already the newest version (1:14.0.01-1).
# fonts-wqy-zenhei is already the newest version (0.9.45-8).
# xfonts-cyrillic is already the newest version (1:1.0.5).
# fonts-noto-color-emoji is already the newest version (2.042-0ubuntu0.22.04.1).
# libcups2 is already the newest version (2.4.1op1-1ubuntu4.7).
# libdbus-1-3 is already the newest version (1.12.20-2ubuntu4.1).
# libdrm2 is already the newest version (2.4.113-2~ubuntu0.22.04.1).
# libfreetype6 is already the newest version (2.11.1+dfsg-1ubuntu0.2).
# libgbm1 is already the newest version (23.0.4-0ubuntu1~22.04.1).
# libglib2.0-0 is already the newest version (2.72.4-0ubuntu2.2).
# libnss3 is already the newest version (2:3.68.2-0ubuntu1.2).
# libpango-1.0-0 is already the newest version (1.50.6+ds-2ubuntu1).
# libwayland-client0 is already the newest version (1.20.0-1ubuntu0.1).
# libx11-6 is already the newest version (2:1.7.5-1ubuntu0.3).
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.5).
# 0 upgraded, 0 newly installed, 0 to remove and 27 not upgraded.
#
# Opening twitter search page...
#
# Scrolling more...
# Scrolling more...
#
# Filling in keywords: Muhaimin since:2023-12-19_00:00:00_WIB until:2023-12-19_23:59:59_WIB
#
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/Muhaimin_2023-12-19.csv
# Total tweets saved: 20
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/Muhaimin_2023-12-19.csv
# Total tweets saved: 40
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/Muhaimin_2023-12-19.csv
# Total tweets saved: 60
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/Muhaimin_2023-12-19.csv
# Total tweets saved: 80
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/Muhaimin_2023-12-19.csv
# Total tweets saved: 100
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/Muhaimin_2023-12-19.csv
# Total tweets saved: 119
#
# --Taking a break, waiting for 10 seconds...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/Muhaimin_2023-12-19.csv
# Total tweets saved: 134
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/Muhaimin_2023-12-19.csv
# Total tweets saved: 144
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/Muhaimin_2023-12-19.csv
# Total tweets saved: 154
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/Muhaimin_2023-12-19.csv
# Total tweets saved: 163
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/Muhaimin_2023-12-19.csv
# Total tweets saved: 169
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/Muhaimin_2023-12-19.csv
# Total tweets saved: 174
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/Muhaimin_2023-12-19.csv
# Total tweets saved: 177
#
# Got some tweets, saving to file...
#
# Got some tweets, saving to file...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/Muhaimin_2023-12-19.csv
# Total tweets saved: 178
#
# Got some tweets, saving to file...
#
# Got some tweets, saving to file...
# Scrolling more...
# Scrolling more...
# Scrolling more...
# Scrolling more...
# Already got 178 tweets, done scrolling...

# %%
# Specify the path to your CSV file
file_path2 = f"tweets-data/{filename2}"

# Read the CSV file into a pandas DataFrame
df2 = pd.read_csv(file_path2)

# sort by created_at
df2 = df2.sort_values(by=['created_at'])

# change datetime to Asia/Jakarta
df2['created_at'] = pd.to_datetime(df2['created_at'])
df2['created_at'] = df2['created_at'].dt.tz_convert('Asia/Jakarta')

# Display the DataFrame
display(df2)
# Out:
#                    created_at               id_str  \
# 30  2023-12-19 02:24:09+07:00  1736829721802158249
# 176 2023-12-19 06:12:34+07:00  1736887206806245557
# 35  2023-12-19 07:06:05+07:00  1736900674720608408
# 16  2023-12-19 07:39:33+07:00  1736909097294086306
# 9   2023-12-19 08:08:13+07:00  1736916309781430430
# ..                        ...                  ...
# 4   2023-12-19 23:05:37+07:00  1737142150238965821
# 79  2023-12-19 23:14:35+07:00  1737144403750473977
# 164 2023-12-19 23:26:26+07:00  1737147386705928586
# 11  2023-12-19 23:26:35+07:00  1737147425499009089
# 23  2023-12-19 23:56:42+07:00  1737155006279921817
#
#                                              full_text  quote_count  \
# 30   Elektabilitas Anies-Muhaimin Naik  Timnas AMIN...            4
# 176  Gus Muhaimin dan Anies Baswedan  keduanya memi...            0
# 35   Anies-Muhaimin akan Evaluasi Semua PSN Jokowi ...            0
# 16   Anies-Muhaimin Tawarkan Revisi UU IKN: Regulas...            1
# 9    Anies-Muhaimin Janjikan Revisi UU IKN: Kontrak...           13
# ..                                                 ...          ...
# 4    Sebuah  Video Narasi Tentang KETAHANAN PANGAN ...            7
# 79   Menurut Muhaimin  tak ada gunanya memenangkan ...            0
# 164                       Setuju dukung anies Muhaimin            0
# 11   Wakil Presiden RI ke-10 dan ke-12 Jusuf Kalla ...           12
# 23   Gusdur : PKB dicuri oleh Muhaimin Iskandar htt...            0
#
#      reply_count  retweet_count  favorite_count lang          user_id_str  \
# 30           116            236             853   in   759692754985242625
# 176            0              0               0   in  1723241739434201088
# 35             0              1               5   in             18129942
# 16             2             17              60   in             18129942
# 9             71            302            1291   in             18129942
# ..           ...            ...             ...  ...                  ...
# 4             15            294             457   in  1335552103457034240
# 79             4              0               3   in             23343960
# 164            0              0               0   in  1625734240108421120
# 11            13            244             578   in             46693036
# 23             0              2               3   in           4839727094
#
#      conversation_id_str         username  \
# 30   1736829721802158249         kumparan
# 176  1736887206806245557  AnyaShelmo38932
# 35   1736900674720608408       tempodotco
# 16   1736909097294086306       tempodotco
# 9    1736916309781430430       tempodotco
# ..                   ...              ...
# 4    1737142150238965821      SOBAT_ANIES
# 79   1737144403750473977        kompascom
# 164  1737147386705928586  Jurney112234567
# 11   1737147425499009089     inilahdotcom
# 23   1737155006279921817          0day_ID
#
#                                              tweet_url  \
# 30   https://twitter.com/kumparan/status/1736829721...
# 176  https://twitter.com/AnyaShelmo38932/status/173...
# 35   https://twitter.com/tempodotco/status/17369006...
# 16   https://twitter.com/tempodotco/status/17369090...
# 9    https://twitter.com/tempodotco/status/17369163...
# ..                                                 ...
# 4    https://twitter.com/SOBAT_ANIES/status/1737142...
# 79   https://twitter.com/kompascom/status/173714440...
# 164  https://twitter.com/Jurney112234567/status/173...
# 11   https://twitter.com/inilahdotcom/status/173714...
# 23   https://twitter.com/0day_ID/status/17371550062...
#
#                                              image_url                location
# 30                                                 NaN                     NaN
# 176                                                NaN                     NaN
# 35                                                 NaN               Indonesia
# 16                                                 NaN               Indonesia
# 9                                                  NaN               Indonesia
# ..                                                 ...                     ...
# 4    https://pbs.twimg.com/ext_tw_video_thumb/17371...  Surakarta, Jawa Tengah
# 79                                                 NaN                 Jakarta
# 164                                                NaN                     NaN
# 11                                                 NaN                     NaN
# 23   https://pbs.twimg.com/ext_tw_video_thumb/17371...                 Jakarta
#
# [178 rows x 14 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 178 entries, 30 to 23
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   created_at           178 non-null    datetime64[ns, Asia/Jakarta]
#  1   id_str               178 non-null    int64
#  2   full_text            178 non-null    object
#  3   quote_count          178 non-null    int64
#  4   reply_count          178 non-null    int64
#  5   retweet_count        178 non-null    int64
#  6   favorite_count       178 non-null    int64
#  7   lang                 178 non-null    object
#  8   user_id_str          178 non-null    int64
#  9   conversation_id_str  178 non-null    int64
#  10  username             178 non-null    object
#  11  tweet_url            178 non-null    object
#  12  image_url            42 non-null     object
#  13  location             137 non-null    object
# dtypes: datetime64[ns, Asia/Jakarta](1), int64(7), object(6)
# memory usage: 20.9+ KB

# %%
# export to csv
try:
    df2.to_csv(f'{path_drive}{filename2}', index=False)
    message2 = f"Berhasil menyimpan file: {filename2}"
    print(message)
except:
    message2 = f"Gagal menyimpan file: {filename2}"
    print(message2)
# Out:
# Berhasil menyimpan file: Anies_2023-12-19.csv

# %% [markdown]
# ## 3. Amin

# %%
# Crawl Data Twitter
paslon3 = 'Amin'
# tanggal = '2023-12-9'
filename3 = f'{paslon3}_{tanggal}.csv'

search_keyword3 = f'{paslon3} since:{tanggal}_00:00:00_WIB until:{tanggal}_23:59:59_WIB'
# limit = 5000

# !npx --yes tweet-harvest@latest -o "{filename3}" -s "{search_keyword3}" -l {limit} --token {token}
# Out:
# Welcome to the Twitter Crawler 🕷️
#
# This script uses Chromium Browser to crawl data from Twitter with *your* Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# up to date, audited 4 packages in 1s
#
# found 0 vulnerabilities
# Installing dependencies...
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 https://deb.nodesource.com/node_20.x nodistro InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-freefont-ttf is already the newest version (20120503-10build1).
# fonts-liberation is already the newest version (1:1.07.4-11).
# libasound2 is already the newest version (1.2.6.1-1ubuntu1).
# libatk-bridge2.0-0 is already the newest version (2.38.0-3).
# libatk1.0-0 is already the newest version (2.36.0-3build1).
# libatspi2.0-0 is already the newest version (2.44.0-3).
# libcairo2 is already the newest version (1.16.0-5ubuntu2).
# libfontconfig1 is already the newest version (2.13.1-4.2ubuntu5).
# libnspr4 is already the newest version (2:4.32-3build1).
# libxcb1 is already the newest version (1.14-3ubuntu3).
# libxcomposite1 is already the newest version (1:0.4.5-1build2).
# libxdamage1 is already the newest version (1:1.1.5-2build2).
# libxext6 is already the newest version (2:1.3.4-1build1).
# libxfixes3 is already the newest version (1:6.0.0-1).
# libxkbcommon0 is already the newest version (1.4.0-1).
# libxrandr2 is already the newest version (2:1.5.2-1build1).
# xfonts-scalable is already the newest version (1:1.0.3-1.2ubuntu1).
# fonts-ipafont-gothic is already the newest version (00303-21ubuntu1).
# fonts-tlwg-loma-otf is already the newest version (1:0.7.3-1).
# fonts-unifont is already the newest version (1:14.0.01-1).
# fonts-wqy-zenhei is already the newest version (0.9.45-8).
# xfonts-cyrillic is already the newest version (1:1.0.5).
# fonts-noto-color-emoji is already the newest version (2.042-0ubuntu0.22.04.1).
# libcups2 is already the newest version (2.4.1op1-1ubuntu4.7).
# libdbus-1-3 is already the newest version (1.12.20-2ubuntu4.1).
# libdrm2 is already the newest version (2.4.113-2~ubuntu0.22.04.1).
# libfreetype6 is already the newest version (2.11.1+dfsg-1ubuntu0.2).
# libgbm1 is already the newest version (23.0.4-0ubuntu1~22.04.1).
# libglib2.0-0 is already the newest version (2.72.4-0ubuntu2.2).
# libnss3 is already the newest version (2:3.68.2-0ubuntu1.2).
# libpango-1.0-0 is already the newest version (1.50.6+ds-2ubuntu1).
# libwayland-client0 is already the newest version (1.20.0-1ubuntu0.1).
# libx11-6 is already the newest version (2:1.7.5-1ubuntu0.3).
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04
# 23    https://pbs.twimg.com/media/GBtj4BzaMAAol3h.jpg
# 25    https://pbs.twimg.com/media/GBtkxTIa0AAR5Fr.jpg
# 10    https://pbs.twimg.com/media/GBtlj_haQAAp7l5.jpg
# 14  https://pbs.twimg.com/ext_tw_video_thumb/17370...
# 24    https://pbs.twimg.com/media/GBto0QIXIAEHCPj.jpg
# 1     https://pbs.twimg.com/media/GAggNNea4AE-MkX.jpg
# 28    https://pbs.twimg.com/media/GBtyseTa8AAjhG3.jpg
# 34    https://pbs.twimg.com/media/GBt7SsPa0AEvVHS.jpg
# 9   https://pbs.twimg.com/ext_tw_video_thumb/17371...
# 21    https://pbs.twimg.com/media/GBuJdegXkAADb6H.jpg
#
#                           location
# 12                             NaN
# 26                       Malaysia
# 22                             NaN
# 31             Islamabad, Pakistan
# 13             Under The Firmament
# 5                  Akramang, Ghana
# 17                  One admin | 22
# 36                 The Netherlands
# 19                             NaN
# 37                             NaN
# 11                             NaN
# 20       she/her | mainly epexvity
# 16  National Capital Region, Repub
# 30                  Gujarat, India
# 4                          Nigeria
# 33                  Lagos, Nigeria
# 35                  United Kingdom
# 7                   Lagos, Nigeria
# 6                              NaN
# 15                             NaN
# 38                             NaN
# 8            Yogyakarta, Indonesia
# 32    Dubai, United Arab Emirates
# 29                             506
# 0               Selangor, Malaysia
# 3               Selangor, Malaysia
# 18                   Kano, Nigeria
# 2                        Indonesia
# 27                             NaN
# 23        RI & CA, USA•MNL•CEB•TAC
# 25                            MUFC
# 10                 K.Lumpur-Taipei
# 14        Eyüp🕌Sultan🕌İstanbul🐬💦🐬💦
# 24                 Kaduna, Nigeria
# 1               Selangor, Malaysia
# 28                            Iran
# 34                             NaN
# 9                              NaN
# 21                Bir Bilinmez Yer

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39 entries, 12 to 21
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   created_at           39 non-null     datetime64[ns, Asia/Jakarta]
#  1   id_str               39 non-null     int64
#  2   full_text            39 non-null     object
#  3   quote_count          39 non-null     int64
#  4   reply_count          39 non-null     int64
#  5   retweet_count        39 non-null     int64
#  6   favorite_count       39 non-null     int64
#  7   lang                 39 non-null     object
#  8   user_id_str          39 non-null     int64
#  9   conversation_id_str  39 non-null     int64
#  10  username             39 non-null     object
#  11  tweet_url            39 non-null     object
#  12  image_url            33 non-null     object
#  13  location             28 non-null     object
# dtypes: datetime64[ns, Asia/Jakarta](1), int64(7), object(6)
# memory usage: 4.6+ KB

# %%
# export to csv
try:
    df3.to_csv(f'{path_drive}{filename3}', index=False)
    message3 = f"Berhasil menyimpan file: {filename3}"
    print(message3)
except:
    message3 = f"Gagal menyimpan file: {filename3}"
    print(message3)
# Out:
# Berhasil menyimpan file: Amin_2023-12-19.csv

# %% [markdown]
# ## Review Data

# %%
# Cek jumlah data yang didapatkan
try:
    num_tweets = len(df)
    print(f"Jumlah tweet dalam dataframe 1 'Anies' adalah {num_tweets}.")
except:
    pass
try:
  num_tweets2 = len(df2)
  print(f"Jumlah tweet dalam dataframe 3 'Muhaimin' adalah {num_tweets2}.")
except:
    pass
try:
  num_tweets3 = len(df3)
  print(f"Jumlah tweet dalam dataframe 3 'Amin' adalah {num_tweets3}.")
except:
    pass
# Out:
# Jumlah tweet dalam dataframe 1 'Anies' adalah 275.
# Jumlah tweet dalam dataframe 3 'Muhaimin' adalah 178.
# Jumlah tweet dalam dataframe 3 'Amin' adalah 39.

# %%
import os
for dirname, _, filenames in os.walk('drive/MyDrive/ScrapingX'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
