# %%
# Import Library
import pandas as pd
import numpy as np

# %%
# Import Dataset
date = "2023-12-29"
df_pres1 = pd.read_csv(f'./ganjar/Ganjar_{date}.csv', lineterminator='\n')
# df_pres2 = pd.read_csv(f'./ganjar/2_Prabowo_{date}.csv', lineterminator='\n')
# df_pres = pd.concat([df_pres1, df_pres2], axis=0, ignore_index=True)
# df_pres = df_pres.drop_duplicates(subset=['full_text'])

df_wpres = pd.read_csv(f'./ganjar/GaMa_{date}.csv', lineterminator='\n')
df_acr = pd.read_csv(f'./ganjar/Mahfud_{date}.csv', lineterminator='\n')

# %%
# count total data
print("Pres:", len(df_pres1), " Wapres:", len(df_wpres), " Akronim:", len(df_acr))
total_data = len(df_pres1) + len(df_wpres) + len(df_acr)
print("Total Data: ", total_data)
# Out:
# Pres: 176  Wapres: 72  Akronim: 103
# Total Data:  351

# %%
# merge dataset
df_pres1['keyword'] = 'Pres'
df_wpres['keyword'] = 'Wapres'
df_acr['keyword'] = 'Akronim'
df = pd.concat([df_pres1, df_wpres, df_acr], axis=0, ignore_index=True)
df
# Out:
#                     created_at               id_str  \
# 0    2023-12-29 17:19:27+07:00  1740678910223040597
# 1    2023-12-29 17:19:51+07:00  1740679011146355156
# 2    2023-12-29 17:21:09+07:00  1740679339644227657
# 3    2023-12-29 17:22:04+07:00  1740679570821652963
# 4    2023-12-29 17:22:33+07:00  1740679690816528815
# ..                         ...                  ...
# 346  2023-12-29 23:50:58+07:00  1740777440660828351
# 347  2023-12-29 23:51:10+07:00  1740777490128441779
# 348  2023-12-29 23:54:32+07:00  1740778337751224703
# 349  2023-12-29 23:55:14+07:00  1740778515493204186
# 350  2023-12-29 23:58:08+07:00  1740779243892818396
#
#                                              full_text  quote_count  \
# 0    WEJANGAN CAPRESKU   Berlokasi di kafe Omah Ray...            0
# 1    Lulusan SMKN Jateng laris Manis lho. Alhamduli...            1
# 2    Orang pintar pasti pilih Ganjar Mahfud  Carina...            7
# ...

# %%
# count duplicate data
print("Duplicate Data: ", df.duplicated().sum())
# Out:
# Duplicate Data:  0

# %%
# count duplicate data based on full_text
print("Duplicate Data by Text: ", df['full_text'].duplicated().sum())
# Out:
# Duplicate Data by Text:  58

# %%
# drop duplicate data based on full_text
df = df.drop_duplicates(subset=['full_text'])
print("Total Data after Drop: ", len(df))
# Out:
# Total Data after Drop:  293

# %%
# sort data by created_at
df = df.sort_values(by=['created_at'])
df
# Out:
#                     created_at               id_str  \
# 242  2023-12-29 01:15:09+07:00  1740436236739936678
# 243  2023-12-29 03:14:15+07:00  1740466211203481979
# 244  2023-12-29 03:38:55+07:00  1740472417003467038
# 245  2023-12-29 05:18:36+07:00  1740497502510383166
# 246  2023-12-29 05:55:27+07:00  1740506777874300999
# ..                         ...                  ...
# 345  2023-12-29 23:50:57+07:00  1740777435598143956
# 346  2023-12-29 23:50:58+07:00  1740777440660828351
# 347  2023-12-29 23:51:10+07:00  1740777490128441779
# 174  2023-12-29 23:54:32+07:00  1740778337751224703
# 350  2023-12-29 23:58:08+07:00  1740779243892818396
#
#                                              full_text  quote_count  \
# 242      @Anele Mbize nge gama https://t.co/KoulocHQnn            0
# 243  Kin Gama Makaranta Kinje Kina Rubuta Thank you...            0
# 244  @ganjarpranowo Kinerja yg sangat di impikan ra...            0
# ...

# %%
len(df_acr)
# Out:
# 103

# %%
# count df with keyword Akronim
len(df[df['keyword'] == 'Akronim'])
# Out:
# 48

# %%
# export dataset
df.to_csv(f'./cleaned_dataset/paslon3/GaMa_{date}.csv', index=False)
